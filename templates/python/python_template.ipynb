# %%
import os
import opendaq as daq
import daq_utils

builder = daq.InstanceBuilder()
if module_path := os.environ.get('OPENDAQ_MODULE_PATH'):
    builder.module_path = module_path
instance = builder.build()

# %%
# Only needed when working with MicroStrain wireless devices
import daq_utils.wireless as wireless
