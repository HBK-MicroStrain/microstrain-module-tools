# %%
import pathlib
import opendaq as daq
import daq_utils

builder = daq.InstanceBuilder()
builder.module_path = str(pathlib.Path().resolve() / 'modules')
instance = builder.build()

# %%
device = instance.add_device('microstrain-wireless://COM46:3000000')

# %%
for device_info in instance.available_devices:
    print('Name:', device_info.name, 'Connection string:', device_info.connection_string)

# %%
inspector = daq_utils.DaqTypeInspector(instance)

# %%
inspector.describe_enum('MSCL_Wireless_InputRange')
# Out:
# Enumerator
# -------------------------------
# range_14_545mV
# range_10_236mV
# range_7_608mV
# range_4_046mV
# range_2_008mV
# range_1_511mV
# range_1_001mV
# range_0_812mV
# range_75mV
# range_37_5mV
# range_18_75mV
# range_9_38mV
# range_4_69mV
# range_2_34mV
# range_1_17mV
# range_0_586mV
# range_70mV
# range_35mV
# range_17_5mV
# range_8_75mV
# range_4_38mV
# range_2_19mV
# range_1_09mV
# range_0_547mV
# range_44mV
# range_30mV
# range_20mV
# range_15mV
# range_10mV
# range_5mV
# range_3mV
# range_2mV
# range_6mV
# range_1mV
# range_50mV
# range_2_5mV
# range_0_6mV
# range_0_35mV
# range_0_1mV
# range_156mV
# range_78_1mV
# range_39mV
# range_19_5mV
# range_9_76mV
# range_4_88mV
# range_2_44mV
# range_1_22mV
# range_10_24V
# range_5_12V
# range_2_56V
# range_0to10_24V
# range_0to5_12V
# range_1_147V
# range_585mV
# range_292_5mV
# range_146_25mV
# range_73_13mV
# range_36_56mV
# range_18_23mV
# range_9_14mV
# range_5_74V
# range_2_93V
# range_1_46V
# range_731_3mV
# range_365_6mV
# range_182_8mV
# range_91_4mV
# range_45_7mV
# range_62_5mV
# range_31_25mV
# range_15_63mV
# range_7_81mV
# range_3_91mV
# range_1_95mV
# range_0_976mV
# range_0_488mV
# range_2G
# range_4G
# range_8G
# range_10G
# range_20G
# range_40G
# range_2_5V
# range_1_25V
# range_625mV
# range_312_5mV
# range_156_25mV
# range_78_125mV
# range_39_063mV
# range_19_532mV
# range_0to2_5V
# range_0to1_25V
# range_0to625mV
# range_0to312_5mV
# range_0to156_25mV
# range_0to78_125mV
# range_0to39_063mV
# range_0to19_532mV
# range_9_766mV
# range_1_35V_or_0to1000000ohm
# range_1_25V_or_0to10000ohm
# range_625mV_or_0to3333_3ohm
# range_312_5mV_or_0to1428_6ohm
# range_156_25mV_or_0to666_67ohm
# range_78_125mV_or_0to322_58ohm
# range_39_0625mV_or_0to158_73ohm
# range_19_5313mV_or_0to78_74ohm
# range_750mV
# range_375mV
# range_187_5mV
# range_93_75mV
# range_46_875mV
# range_23_438mV
# range_11_719mV
# range_5_859mV
# range_0to1_5V
# range_0to750mV
# range_0to375mV
# range_0to187_5mV
# range_0to93_75mV
# range_0to46_875mV
# range_0to23_438mV
# range_0to11_719mV
# range_1_5V
# range_1_35V
# range_0to1000000ohm
# range_0to10000ohm
# range_0to3333_3ohm
